# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
conflict_df=pd.read_csv('conflict_data_rwa.csv')
agriculture_df=pd.read_csv('agriculture-and-rural-development_rwa.csv')
coping_df=pd.read_csv('dbo-copingstrategiesindexes.csv')
economy_df=pd.read_csv('economy-and-growth_rwa.csv')
health_df=pd.read_csv('health_rwa.csv', skiprows=1)
indicators_df=pd.read_csv('indicators_rwa.csv')
social_df=pd.read_csv('social-development_rwa.csv')
labor_df=pd.read_csv('social-protection-and-labor_rwa.csv')
urban_df=pd.read_csv('urban-development_rwa.csv')

# %%
health_df
# Out:
#      #country+name #country+code  #date+year  \
# 0           Rwanda           RWA        2015
# 1           Rwanda           RWA        2015
# 2           Rwanda           RWA        2010
# 3           Rwanda           RWA        2005
# 4           Rwanda           RWA        2000
# ...            ...           ...         ...
# 9428        Rwanda           RWA        1994
# 9429        Rwanda           RWA        1993
# 9430        Rwanda           RWA        1992
# 9431        Rwanda           RWA        1991
# 9432        Rwanda           RWA        1990
#
#                                         #indicator+name       #indicator+code  \
# 0     Proportion of women subjected to physical and/...        SG.VAW.1549.ZS
# 1     Women who believe a husband is justified in be...        SG.VAW.ARGU.ZS
# 2     Women who believe a husband is justified in be...        SG.VAW.ARGU.ZS
# 3     Women who believe a husband is justified in be...        SG.VAW.ARGU.ZS
# ...

# %%
health_df.columns = health_df.columns.droplevel(1)
health_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-e19903290b6c> in <module>
# ----> 1 health_df.columns = health_df.columns.droplevel(1)
#       2 health_df
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\indexes\base.py in droplevel(self, level)
#    1607             level = [level]
#    1608
# -> 1609         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1610
#    1611         return self._drop_level_numbers(levnums)
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\indexes\base.py in <genexpr>(.0)
#    1607             level = [level]
#    1608
# -> 1609         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1610
#    1611         return self._drop_level_numbers(levnums)
#
# ...
